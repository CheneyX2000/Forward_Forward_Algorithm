# %%
import numpy as np
from sklearn.datasets import fetch_openml
import tensorflow as tf
from FFLayer import FFLayer
from FFNetwork import FFNetwork
import time

# %%
#def load_mnist():
#    """
#    load mnist data set
#    """
#    print("Loading MNIST dataset...")
#    X, y = fetch_openml('mnist_784', return_X_y=True, as_frame=False)
#    X = X.astype(np.float32) / 255.0  # unify to [0,1]
#    y = y.astype(np.int32)
#    
#    # segment data set to get training set and testing set
#    X_train, X_test = X[:60000], X[60000:]
#    y_train, y_test = y[:60000], y[60000:]
#    
#    print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
#    print(f"Pixel range: [{X_train.min():.3f}, {X_train.max():.3f}]")
#    return X_train, X_test, y_train, y_test

def load_mnist():
    """
    load mnist data set using TensorFlow
    """
    print("Loading MNIST dataset...")
    
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
    
    X_train = X_train.reshape(60000, 784).astype(np.float32) / 255.0
    X_test = X_test.reshape(10000, 784).astype(np.float32) / 255.0
    
    y_train = y_train.astype(np.int32)
    y_test = y_test.astype(np.int32)
    
    print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
    print(f"Pixel range: [{X_train.min():.3f}, {X_train.max():.3f}]")
    return X_train, X_test, y_train, y_test

# %%
def test_basic_functionality():
    """
    test the basic functionalities of the network
    """
    print("\n=== base test ===")
    
    # build a small network for test
    network = FFNetwork([794, 100, 50, 10])  # input is 784+10=794
    
    # test single sample
    x_sample = np.random.rand(784)
    y_sample = 3
    
    # test construct_samples
    pos, neg = network.construct_samples(x_sample, y_sample)
    print(f"Sample construction: pos.shape={pos.shape}, neg.shape={neg.shape}")
    print(f"Positive label position: {np.argmax(pos[:10])}")
    print(f"Negative label position: {np.argmax(neg[:10])}")
    
    # test predict
    pred = network.predict(x_sample)
    probs = network.predict_probabilities(x_sample)
    print(f"Random prediction: {pred}, max_prob: {probs.max():.4f}")
    
    print("base test passed")

# %%
def run_small_scale_experiment():
    """
    run small scale experiment
    """
    print("\n=== small scale experiment ===")
    
    # load data
    X_train, X_test, y_train, y_test = load_mnist()
    
    # build net: input layer is 794-dim (784 pixel + 10 number as one-hot), hidden layers are 500 and 300, output layer is 10-dim
    network = FFNetwork([794, 500, 300, 10])
    print(f"Network architecture: {network.layer_sizes}")
    
    # small scale training
    print("\nstart trainin...")
    start_time = time.time()
    
    # test on small data set with 5 epoch
    network.train(
        X_train=X_train[:1000], # train with 1000 test samples
        y_train=y_train[:1000], 
        X_test=X_test[:1000],  # test with 1000 test samples
        y_test=y_test[:1000],
        epochs=5
    )
    
    training_time = time.time() - start_time
    print(f"\ntraining completed, time used: {training_time:.2f} second")
    
    # detailed evaluation
    print("\n=== detailed evaluation ===")
    test_accuracy = network.evaluate(X_test[:1000], y_test[:1000])
    print(f"accuracy on the test set: {test_accuracy:.4f}")
    
    # analyze some predictions
    print("\nsample prediction analysis:")
    for i in range(5):
        true_label = y_test[i]
        pred_label = network.predict(X_test[i])
        probs = network.predict_probabilities(X_test[i])
        confidence = probs.max()
        print(f"sample{i}: true_label={true_label}, predicted_label={pred_label}, confidence={confidence:.4f}")

# %%
def run_performance_comparison():
    """
    a test for performance comparison of different architectures
    """
    print("\n=== performance comparison of different architectures ===")
    
    X_train, X_test, y_train, y_test = load_mnist()
    
    # test the performance of different architectures
    architectures = [
        [794, 200, 10],          # shallow
        [794, 500, 300, 10],     # medium
        [794, 800, 400, 200, 10] # deep
    ]
    
    results = []
    
    for arch in architectures:
        print(f"\ntest architecture: {arch}")
        network = FFNetwork(arch)
        
        start_time = time.time()
        network.train(
            X_train=X_train[:500],
            y_train=y_train[:500],
            X_test=X_test[:500],
            y_test=y_test[:500],
            epochs=3,
        )
        train_time = time.time() - start_time
        
        # evaluate performance
        accuracy = network.evaluate(X_test[:500], y_test[:500])
        
        results.append({
            'architecture': arch,
            'layers': len(arch) - 1,
            'parameters': sum(arch[i] * arch[i+1] for i in range(len(arch)-1)),
            'accuracy': accuracy,
            'train_time': train_time
        })
        
        print(f"accuracy: {accuracy:.4f}, training time: {train_time:.2f} second")
    
    # print results
    print("\n=== performance comparison of different architectures  ===")
    print("architecture\t\tnumber_of_layer\tparemeter_number\taccuracy\ttraining_time")
    print("-" * 60)
    for result in results:
        arch_str = str(result['architecture'])[:20]
        print(f"{arch_str:<20}\t{result['layers']}\t{result['parameters']}\t{result['accuracy']:.4f}\t{result['train_time']:.2f}s")

# %%
if __name__ == "__main__":
    print("Forward-Forward Algo test")
    print("=" * 50)
    
    # base test
    test_basic_functionality()
    
    # small-scale experiment
    run_small_scale_experiment()
    
    # performance comparison (optional)
    print("\n run performance comparison? type 'y' to continue")
    user_input = input().lower().strip()
    if user_input == 'y':
        run_performance_comparison()
    
    print("\ntest completed")
# Out:
# Forward-Forward Algo test
# ==================================================
#
# === base test ===
# Sample construction: pos.shape=(794,), neg.shape=(794,)
# Positive label position: 3
# Negative label position: 1
# Random prediction: 3, max_prob: 0.1859
# base test passed
#
# === small scale experiment ===
# Loading MNIST dataset...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1472, in HTTPSConnection.connect(self)
#    1470 "Connect to a host on a given (SSL) port."
# -> 1472 super().connect()
#    1474 if self._tunnel_host:
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\http\client.py:1003, in HTTPConnection.connect(self)
#    1002 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1003 self.sock = self._create_connection(
#    1004     (self.host,self.port), self.timeout, self.source_address)
#    1005 # Might fail in OSs that don't implement TCP_NODELAY
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\socket.py:864, in create_connection(address, timeout, source_address, all_errors)
#     863 if not all_errors:
# --> 864     raise exceptions[0]
#     865 raise ExceptionGroup("create_connection failed", exceptions)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       6 test_basic_functionality()
#       8 # small-scale experiment
# ----> 9 run_small_scale_experiment()
#      11 # performance comparison (optional)
#      12 print("\n run performance comparison? type 'y' to continue")
#
# Cell In[11], line 8, in run_small_scale_experiment()
#       5 print("\n=== small scale experiment ===")
#       7 # load data
# ----> 8 X_train, X_test, y_train, y_test = load_mnist()
#      10 # build net: input layer is 794-dim (784 pixel + 10 number as one-hot), hidden layers are 500 and 300, output layer is 10-dim
#      11 network = FFNetwork([794, 500, 300, 10])
#
# Cell In[9], line 6, in load_mnist()
#       2 """
#       3 load mnist data set
#       4 """
#       5 print("Loading MNIST dataset...")
# ----> 6 X, y = fetch_openml('mnist_784', return_X_y=True, as_frame=False)
#       7 X = X.astype(np.float32) / 255.0  # unify to [0,1]
#       8 y = y.astype(np.int32)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:1012, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser, read_csv_kwargs)
#    1006     if data_id is not None:
#    1007         raise ValueError(
#    1008             "Dataset data_id={} and name={} passed, but you can only "
#    1009             "specify a numeric data_id or a name, not "
#    1010             "both.".format(data_id, name)
#    1011         )
# -> 1012     data_info = _get_data_info_by_name(
#    1013         name, version, data_home, n_retries=n_retries, delay=delay
#    1014     )
#    1015     data_id = data_info["did"]
#    1016 elif data_id is not None:
#    1017     # from the previous if statement, it is given that name is None
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:303, in _get_data_info_by_name(name, version, data_home, n_retries, delay)
#     301 url = _SEARCH_NAME.format(name) + "/status/active/"
#     302 error_msg = "No active dataset {} found.".format(name)
# --> 303 json_data = _get_json_content_from_openml_api(
#     304     url,
#     305     error_msg,
#     306     data_home=data_home,
#     307     n_retries=n_retries,
#     308     delay=delay,
#     309 )
#     310 res = json_data["data"]["dataset"]
#     311 if len(res) > 1:
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:247, in _get_json_content_from_openml_api(url, error_message, data_home, n_retries, delay)
#     244         return json.loads(response.read().decode("utf-8"))
#     246 try:
# --> 247     return _load_json()
#     248 except HTTPError as error:
#     249     # 412 is an OpenML specific error code, indicating a generic error
#     250     # (e.g., data not found)
#     251     if error.code != 412:
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:66, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      64     return f(*args, **kw)
#      65 try:
# ---> 66     return f(*args, **kw)
#      67 except URLError:
#      68     raise
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:242, in _get_json_content_from_openml_api.<locals>._load_json()
#     239 @_retry_with_clean_cache(url, data_home=data_home)
#     240 def _load_json():
#     241     with closing(
# --> 242         _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     243     ) as response:
#     244         return json.loads(response.read().decode("utf-8"))
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:174, in _open_openml_url(url, data_home, n_retries, delay)
#     167 try:
#     168     # Create a tmpdir as a subfolder of dir_name where the final file will
#     169     # be moved to if the download is successful. This guarantees that the
#     170     # renaming operation to the final location is atomic to ensure the
#     171     # concurrence safety of the dataset caching mechanism.
#     172     with TemporaryDirectory(dir=dir_name) as tmpdir:
#     173         with closing(
# --> 174             _retry_on_network_error(n_retries, delay, req.full_url)(urlopen)(
#     175                 req
#     176             )
#     177         ) as fsrc:
#     178             opener: Callable
#     179             if is_gzip_encoded(fsrc):
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\site-packages\sklearn\datasets\_openml.py:102, in _retry_on_network_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     100 while True:
#     101     try:
# --> 102         return f(*args, **kwargs)
#     103     except (URLError, TimeoutError) as e:
#     104         # 412 is a specific OpenML error code.
#     105         if isinstance(e, HTTPError) and e.code == 412:
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File c:\Users\13048\.conda\envs\forward_forward_env\Lib\urllib\request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
